# %% [markdown]
# ---
#
# Reconecte ao Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
DRIVE_DIRECTORY = "curso_ml"
DRIVE_DIRECTORY = os.path.join("/content/drive/MyDrive", DRIVE_DIRECTORY)

# %% [markdown]
# ---

# %%
import pickle

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.neural_network import MLPClassifier
from yellowbrick.classifier import ConfusionMatrix

# %% [markdown]
# # Rede neural artificial

# %% [markdown]
# Comece recuperando os dados preditores, de treino e de teste, a partir do arquivo `cover_type.pkl` salvo na pasta do Drive. Lembre-se de que você deve instanciar as variáveis `X` e `y`, dos splits `train` e `test`,  na mesma ordem em que salvou.

# %%
with open(os.path.join(DRIVE_DIRECTORY, "cover_type.pkl"), "rb") as f:
  X_train, y_train, X_test, y_test = pickle.load(f)

# %% [markdown]
# Instancie e ajuste um classificador do tipo `MLPClassifier`. Altere os valores padrão dos parâmetros, utilizando `verbose=True`, e `hidden_layer_sizes=(100, 50)`.

# %%
mlp_classifier = MLPClassifier(verbose=True, hidden_layer_sizes=(100, 50))
mlp_classifier.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 1.45552248
# Iteration 2, loss = 0.97175051
# Iteration 3, loss = 0.82133827
# Iteration 4, loss = 0.73928199
# Iteration 5, loss = 0.68964497
# Iteration 6, loss = 0.65706527
# Iteration 7, loss = 0.63580883
# Iteration 8, loss = 0.62011685
# Iteration 9, loss = 0.60920331
# Iteration 10, loss = 0.59914620
# Iteration 11, loss = 0.59002159
# Iteration 12, loss = 0.58258504
# Iteration 13, loss = 0.57515816
# Iteration 14, loss = 0.56622034
# Iteration 15, loss = 0.56222572
# Iteration 16, loss = 0.55581595
# Iteration 17, loss = 0.54914259
# Iteration 18, loss = 0.54170686
# Iteration 19, loss = 0.53651309
# Iteration 20, loss = 0.53060567
# Iteration 21, loss = 0.52594560
# Iteration 22, loss = 0.52120868
# Iteration 23, loss = 0.51638714
# Iteration 24, loss = 0.51662879
# Iteration 25, loss = 0.51113867
# Iteration 26, loss = 0.50335692
# Iteration 27, loss = 0.49838187
# Iteration 28, loss = 0.49287398
# Iteration 29, loss = 0.49067138
# Iteration 30, loss = 0.48470238
# Iteration 31, loss = 0.48171295
# Iteration 32, loss = 0.47856530
# Iteration 33, loss = 0.47238174
# Iteration 34, loss = 0.47051378
# Iteration 35, loss = 0.46516237
# Iteration 36, loss = 0.46632362
# Iteration 37, loss = 0.46585845
# Iteration 38, loss = 0.45673853
# Iteration 39, loss = 0.45704302
# Iteration 40, loss = 0.45059578
# Iteration 41, loss = 0.44748216
# Iteration 42, loss = 0.44580809
# Iteration 43, loss = 0.44004868
# Iteration 44, loss = 0.43926763
# Iteration 45, loss = 0.43544103
# Iteration 46, loss = 0.43329519
# Iteration 47, loss = 0.43331384
# Iteration 48, loss = 0.43067630
# Iteration 49, loss = 0.43066473
# Iteration 50, loss = 0.42065861
# Iteration 51, loss = 0.41825787
# Iteration 52, loss = 0.41839759
# Iteration 53, loss = 0.41441447
# Iteration 54, loss = 0.41394194
# Iteration 55, loss = 0.40781111
# Iteration 56, loss = 0.40707435
# Iteration 141, loss = 0.26712873
# Iteration 142, loss = 0.26299303
# Iteration 143, loss = 0.26291447
# Iteration 144, loss = 0.26027360
# Iteration 145, loss = 0.25970137
# Iteration 146, loss = 0.26360746
# Iteration 147, loss = 0.25718115
# Iteration 148, loss = 0.26100509
# Iteration 149, loss = 0.25577741
# Iteration 150, loss = 0.25387283
# Iteration 151, loss = 0.25258008
# Iteration 152, loss = 0.25002700
# Iteration 153, loss = 0.24876008
# Iteration 154, loss = 0.25265733
# Iteration 155, loss = 0.25024132
# Iteration 156, loss = 0.25100029
# Iteration 157, loss = 0.25231288
# Iteration 158, loss = 0.24641292
# Iteration 159, loss = 0.24967513
# Iteration 160, loss = 0.24496127
# Iteration 161, loss = 0.24060576
# Iteration 162, loss = 0.24298855
# Iteration 163, loss = 0.24159357
# Iteration 164, loss = 0.24180192
# Iteration 165, loss = 0.23780471
# Iteration 166, loss = 0.23838851
# Iteration 167, loss = 0.23949247
# Iteration 168, loss = 0.23469175
# Iteration 169, loss = 0.23981000
# Iteration 170, loss = 0.23391532
# Iteration 171, loss = 0.23203736
# Iteration 172, loss = 0.22988581
# Iteration 173, loss = 0.23354410
# Iteration 174, loss = 0.23208329
# Iteration 175, loss = 0.22493834
# Iteration 176, loss = 0.22488093
# Iteration 177, loss = 0.22547936
# Iteration 178, loss = 0.22638306
# Iteration 179, loss = 0.22474291
# Iteration 180, loss = 0.22476465
# Iteration 181, loss = 0.22353899
# Iteration 182, loss = 0.22158715
# Iteration 183, loss = 0.22274869
# Iteration 184, loss = 0.21796497
# Iteration 185, loss = 0.21792313
# Iteration 186, loss = 0.21845159
# Iteration 187, loss = 0.22491177
# Iteration 188, loss = 0.21625387
# Iteration 189, loss = 0.21684379
# Iteration 190, loss = 0.21488927
# Iteration 191, loss = 0.21385896
# Iteration 192, loss = 0.21780999
# Iteration 193, loss = 0.21397424
# Iteration 194, loss = 0.21415738
# Iteration 195, loss = 0.20977153
# Iteration 196, loss = 0.20847775
# Iteration 197, loss = 0.20824279
# Iteration 198, loss = 0.20737300
# Iteration 199, loss = 0.20820969
# Iteration 200, loss = 0.21291588
# /usr/local/lib/python3.12/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(100, 50), verbose=True)

# %% [markdown]
# Faça e exiba a predição no split de teste.

# %%
y_pred = mlp_classifier.predict(X_test)

# %%
y_pred
# Out:
# array([4, 4, 1, ..., 6, 6, 2])

# %% [markdown]
# Calcule a acurácia.

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.7776

# %% [markdown]
# Exiba a matriz de confusão.

# %%
cm = ConfusionMatrix(mlp_classifier)
cm.fit(X_train, y_train)
cm.score(X_test, y_test)
# Out:
# 0.7776

# %% [markdown]
# Exiba o reporte de classificação.

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.41      0.50      0.45        34
#            1       0.44      0.69      0.54        16
#            2       0.46      0.43      0.45        67
#            3       0.80      0.76      0.78        87
#            4       0.83      0.81      0.82      1230
#            5       0.70      0.67      0.68       156
#            6       0.76      0.79      0.78       910
#
#     accuracy                           0.78      2500
#    macro avg       0.63      0.66      0.64      2500
# weighted avg       0.78      0.78      0.78      2500
